# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r=requests.get('https://api.github.com/events')
r.text

import json
json.loads(r.text)
# Out:
# [{'id': '12689197993',
#   'type': 'PushEvent',
#   'actor': {'id': 33738976,
#    'login': 'jerryrox',
#    'display_login': 'jerryrox',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jerryrox',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33738976?'},
#   'repo': {'id': 216285404,
#    'name': 'jerryrox/project-beats-framework',
#    'url': 'https://api.github.com/repos/jerryrox/project-beats-framework'},
#   'payload': {'push_id': 5260359765,
#    'size': 6,
#    'distinct_size': 6,
#    'ref': 'refs/heads/develop',
#    'head': 'ea912cda06547a07780e6815adaacbf8f87f5bb5',
#    'before': '7662188ed0954d8daa49c857dc2c4b84ef7156f7',
#    'commits': [{'sha': '63e6faad1ec870e4bb1c6f841b64b0bd7ddc6939',
#      'author': {'email': 'jerryrox@live.co.kr', 'name': 'Jerry Kim'},
#      'message': 'Make DependencyContainer cache itself by default.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jerryrox/project-beats-framework/commits/63e6faad1ec870e4bb1c6f841b64b0bd7ddc6939'},
#     {'sha': 'bd02f5814263d37d81d3dbe04d6ee4e8eb2ef927',
#      'author': {'email': 'jerryrox@live.co.kr', 'name': 'Jerry Kim'},
#      'message': 'Fix potential bug',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jerryrox/project-beats-framework/commits/bd02f5814263d37d81d3dbe04d6ee4e8eb2ef927'},
#     {'sha': 'a8ec418e22a356473f6cadeccd3361580b842b53',
#      'author': {'email': 'jerryrox@live.co.kr', 'name': 'Jerry Kim'},
#      'message': 'Created TestEnvironment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jerryrox/project-beats-framework/commits/a8ec418e22a356473f6cadeccd3361580b842b53'},
#     {'sha': '140473a117496707566b9b9dbaa96444ee8d58ca',
#      'author': {'email': 'jerryrox@live.co.kr', 'name': 'Jerry Kim'},
#      'message': 'Create TestKeyBinding.cs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jerryrox/project-beats-framework/commits/140473a117496707566b9b9dbaa96444ee8d58ca'},
#     {'sha': 'a808cd8e9d628150a0ffa1e3677dd40e300bac2e',
#      'author': {'email': 'jerryrox@live.co.kr', 'name': 'Jerry Kim'},
#      'message': 'Redesigned key-bound action testing',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jerryrox/project-beats-framework/commits/a808cd8e9d628150a0ffa1e3677dd40e300bac2e'},
#     {'sha': 'ea912cda06547a07780e6815adaacbf8f87f5bb5',
#      'author': {'email': 'jerryrox@live.co.kr', 'name': 'Jerry Kim'},
#      'message': "Merge branch 'feature/test-framework' into develop",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jerryrox/project-beats-framework/commits/ea912cda06547a07780e6815adaacbf8f87f5bb5'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197992',
#   'type': 'PushEvent',
#   'actor': {'id': 57080920,
#    'login': 'exploitpnk',
#    'display_login': 'exploitpnk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/exploitpnk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57080920?'},
#   'repo': {'id': 259151450,
#    'name': 'exploitpnk/holbertonschool-low_level_programming',
#    'url': 'https://api.github.com/repos/exploitpnk/holbertonschool-low_level_programming'},
#   'payload': {'push_id': 5260359761,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cf72334532f7e6465f7097617a6d3ca7ab901fd3',
#    'before': '67b3439045f3df0fc628f9f11791af61e923e39c',
#    'commits': [{'sha': 'cf72334532f7e6465f7097617a6d3ca7ab901fd3',
#      'author': {'email': 'exploitpnk@gmail.com', 'name': 'exploitpnk'},
#      'message': '[Add] file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/exploitpnk/holbertonschool-low_level_programming/commits/cf72334532f7e6465f7097617a6d3ca7ab901fd3'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197994',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 45835198,
#    'login': 'TrackRunny',
#    'display_login': 'TrackRunny',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TrackRunny',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45835198?'},
#   'repo': {'id': 197040175,
#    'name': 'TrackRunny/LinuxBoi',
#    'url': 'https://api.github.com/repos/TrackRunny/LinuxBoi'},
#   'payload': {'action': 'closed',
#    'number': 62,
#    'pull_request': {'url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls/62',
#     'id': 437431905,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDM3NDMxOTA1',
#     'html_url': 'https://github.com/TrackRunny/LinuxBoi/pull/62',
#     'diff_url': 'https://github.com/TrackRunny/LinuxBoi/pull/62.diff',
#     'patch_url': 'https://github.com/TrackRunny/LinuxBoi/pull/62.patch',
#     'issue_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues/62',
#     'number': 62,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump certifi from 2020.4.5.2 to 2020.6.20',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [certifi](https://github.com/certifi/python-certifi) from 2020.4.5.2 to 2020.6.20.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/certifi/python-certifi/commit/f7e30d82841ef508158da706b7743b2d34018fb1"><code>f7e30d8</code></a> 2020.06.20</li>\n<li>See full diff in <a href="https://github.com/certifi/python-certifi/compare/2020.04.05.2...2020.06.20">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=certifi&package-manager=pip&previous-version=2020.4.5.2&new-version=2020.6.20)](https://dependabot.com/compatibility-score/?dependency-name=certifi&package-manager=pip&previous-version=2020.4.5.2&new-version=2020.6.20)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n- `@dependabot badge me` will comment on this PR with code to add a "Dependabot enabled" badge to your readme\n\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\n- Update frequency (including time of day and day of week)\n- Pull request limits (per update run and/or open at any time)\n- Out-of-range updates (receive only lockfile updates, if desired)\n- Security updates (receive only security updates, if desired)\n\n\n\n</details>',
#     'created_at': '2020-06-20T16:26:45Z',
#     'updated_at': '2020-06-21T04:16:55Z',
#     'closed_at': '2020-06-21T04:16:55Z',
#     'merged_at': '2020-06-21T04:16:55Z',
#     'merge_commit_sha': 'c6efeb66db82caf9bbc245b533434d5452843172',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1902497035,
#       'node_id': 'MDU6TGFiZWwxOTAyNDk3MDM1',
#       'url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 1902498066,
#       'node_id': 'MDU6TGFiZWwxOTAyNDk4MDY2',
#       'url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/labels/python',
#       'name': 'python',
#       'color': '387eb8',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls/62/commits',
#     'review_comments_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls/62/comments',
#     'review_comment_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues/62/comments',
#     'statuses_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/statuses/324f42682bbe6855ab79fa1d4aa22fa7f3e840fd',
#     'head': {'label': 'TrackRunny:dependabot/pip/certifi-2020.6.20',
#      'ref': 'dependabot/pip/certifi-2020.6.20',
#      'sha': '324f42682bbe6855ab79fa1d4aa22fa7f3e840fd',
#      'user': {'login': 'TrackRunny',
#       'id': 45835198,
#       'node_id': 'MDQ6VXNlcjQ1ODM1MTk4',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/45835198?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/TrackRunny',
#       'html_url': 'https://github.com/TrackRunny',
#       'followers_url': 'https://api.github.com/users/TrackRunny/followers',
#       'following_url': 'https://api.github.com/users/TrackRunny/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/TrackRunny/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/TrackRunny/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/TrackRunny/subscriptions',
#       'organizations_url': 'https://api.github.com/users/TrackRunny/orgs',
#       'repos_url': 'https://api.github.com/users/TrackRunny/repos',
#       'events_url': 'https://api.github.com/users/TrackRunny/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/TrackRunny/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 197040175,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTcwNDAxNzU=',
#       'name': 'LinuxBoi',
#       'full_name': 'TrackRunny/LinuxBoi',
#       'private': False,
#       'owner': {'login': 'TrackRunny',
#        'id': 45835198,
#        'node_id': 'MDQ6VXNlcjQ1ODM1MTk4',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/45835198?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/TrackRunny',
#        'html_url': 'https://github.com/TrackRunny',
#        'followers_url': 'https://api.github.com/users/TrackRunny/followers',
#        'following_url': 'https://api.github.com/users/TrackRunny/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/TrackRunny/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/TrackRunny/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/TrackRunny/subscriptions',
#        'organizations_url': 'https://api.github.com/users/TrackRunny/orgs',
#        'repos_url': 'https://api.github.com/users/TrackRunny/repos',
#        'events_url': 'https://api.github.com/users/TrackRunny/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/TrackRunny/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/TrackRunny/LinuxBoi',
#       'description': 'Yet, another Discord Bot aiming to help / teach people about Linux.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/TrackRunny/LinuxBoi',
#       'forks_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/forks',
#       'keys_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/teams',
#       'hooks_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/events',
#       'assignees_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/tags',
#       'blobs_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/languages',
#       'stargazers_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/subscription',
#       'commits_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/merges',
#       'archive_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/downloads',
#       'issues_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/deployments',
#       'created_at': '2019-07-15T17:05:26Z',
#       'updated_at': '2020-06-19T00:24:13Z',
#       'pushed_at': '2020-06-21T04:16:54Z',
#       'git_url': 'git://github.com/TrackRunny/LinuxBoi.git',
#       'ssh_url': 'git@github.com:TrackRunny/LinuxBoi.git',
#       'clone_url': 'https://github.com/TrackRunny/LinuxBoi.git',
#       'svn_url': 'https://github.com/TrackRunny/LinuxBoi',
#       'homepage': '',
#       'size': 51475,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 6,
#       'default_branch': 'master'}},
#     'base': {'label': 'TrackRunny:master',
#      'ref': 'master',
#      'sha': 'f3468aac8775a39b1a5e3a66243c286eb796e8dd',
#      'user': {'login': 'TrackRunny',
#       'id': 45835198,
#       'node_id': 'MDQ6VXNlcjQ1ODM1MTk4',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/45835198?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/TrackRunny',
#       'html_url': 'https://github.com/TrackRunny',
#       'followers_url': 'https://api.github.com/users/TrackRunny/followers',
#       'following_url': 'https://api.github.com/users/TrackRunny/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/TrackRunny/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/TrackRunny/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/TrackRunny/subscriptions',
#       'organizations_url': 'https://api.github.com/users/TrackRunny/orgs',
#       'repos_url': 'https://api.github.com/users/TrackRunny/repos',
#       'events_url': 'https://api.github.com/users/TrackRunny/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/TrackRunny/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 197040175,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTcwNDAxNzU=',
#       'name': 'LinuxBoi',
#       'full_name': 'TrackRunny/LinuxBoi',
#       'private': False,
#       'owner': {'login': 'TrackRunny',
#        'id': 45835198,
#        'node_id': 'MDQ6VXNlcjQ1ODM1MTk4',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/45835198?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/TrackRunny',
#        'html_url': 'https://github.com/TrackRunny',
#        'followers_url': 'https://api.github.com/users/TrackRunny/followers',
#        'following_url': 'https://api.github.com/users/TrackRunny/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/TrackRunny/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/TrackRunny/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/TrackRunny/subscriptions',
#        'organizations_url': 'https://api.github.com/users/TrackRunny/orgs',
#        'repos_url': 'https://api.github.com/users/TrackRunny/repos',
#        'events_url': 'https://api.github.com/users/TrackRunny/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/TrackRunny/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/TrackRunny/LinuxBoi',
#       'description': 'Yet, another Discord Bot aiming to help / teach people about Linux.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/TrackRunny/LinuxBoi',
#       'forks_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/forks',
#       'keys_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/teams',
#       'hooks_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/events',
#       'assignees_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/tags',
#       'blobs_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/languages',
#       'stargazers_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/subscription',
#       'commits_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/merges',
#       'archive_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/downloads',
#       'issues_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/TrackRunny/LinuxBoi/deployments',
#       'created_at': '2019-07-15T17:05:26Z',
#       'updated_at': '2020-06-19T00:24:13Z',
#       'pushed_at': '2020-06-21T04:16:54Z',
#       'git_url': 'git://github.com/TrackRunny/LinuxBoi.git',
#       'ssh_url': 'git@github.com:TrackRunny/LinuxBoi.git',
#       'clone_url': 'https://github.com/TrackRunny/LinuxBoi.git',
#       'svn_url': 'https://github.com/TrackRunny/LinuxBoi',
#       'homepage': '',
#       'size': 51475,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 6,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls/62'},
#      'html': {'href': 'https://github.com/TrackRunny/LinuxBoi/pull/62'},
#      'issue': {'href': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues/62'},
#      'comments': {'href': 'https://api.github.com/repos/TrackRunny/LinuxBoi/issues/62/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls/62/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/TrackRunny/LinuxBoi/pulls/62/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/TrackRunny/LinuxBoi/statuses/324f42682bbe6855ab79fa1d4aa22fa7f3e840fd'}},
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'TrackRunny',
#      'id': 45835198,
#      'node_id': 'MDQ6VXNlcjQ1ODM1MTk4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/45835198?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/TrackRunny',
#      'html_url': 'https://github.com/TrackRunny',
#      'followers_url': 'https://api.github.com/users/TrackRunny/followers',
#      'following_url': 'https://api.github.com/users/TrackRunny/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/TrackRunny/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/TrackRunny/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/TrackRunny/subscriptions',
#      'organizations_url': 'https://api.github.com/users/TrackRunny/orgs',
#      'repos_url': 'https://api.github.com/users/TrackRunny/repos',
#      'events_url': 'https://api.github.com/users/TrackRunny/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/TrackRunny/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197990',
#   'type': 'PushEvent',
#   'actor': {'id': 30015728,
#    'login': 'p1ass',
#    'display_login': 'p1ass',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/p1ass',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30015728?'},
#   'repo': {'id': 266313259,
#    'name': 'p1ass/midare',
#    'url': 'https://api.github.com/repos/p1ass/midare'},
#   'payload': {'push_id': 5260359760,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b7690603c69d95ed300db86b48685df4dd83adf9',
#    'before': '0846e5c391b125a905c489414bcd918ec56f71e7',
#    'commits': [{'sha': '7d7d3b131fe06d3c5bdfe7c848c66a5b14a934ae',
#      'author': {'email': 'naokikishi.kyoto@gmail.com', 'name': 'Naoki Kishi'},
#      'message': 'カレンダーをlazyに読み込む',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/p1ass/midare/commits/7d7d3b131fe06d3c5bdfe7c848c66a5b14a934ae'},
#     {'sha': 'b7690603c69d95ed300db86b48685df4dd83adf9',
#      'author': {'email': 'naokikishi.kyoto@gmail.com', 'name': 'Naoki Kishi'},
#      'message': 'Merge pull request #75 from p1ass/lazy\n\nカレンダーをlazyに読み込む',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/p1ass/midare/commits/b7690603c69d95ed300db86b48685df4dd83adf9'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197989',
#   'type': 'PushEvent',
#   'actor': {'id': 67129207,
#    'login': 'aksu07',
#    'display_login': 'aksu07',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aksu07',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67129207?'},
#   'repo': {'id': 273755906,
#    'name': 'aksu07/git_proje_turkce',
#    'url': 'https://api.github.com/repos/aksu07/git_proje_turkce'},
#   'payload': {'push_id': 5260359754,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '601d237744dd8f9a925c1093d77897a9e0cb0286',
#    'before': '8bd19fe7007f7d67409bc336f8b88434fe104f23',
#    'commits': [{'sha': '601d237744dd8f9a925c1093d77897a9e0cb0286',
#      'author': {'email': '67129207+aksu07@users.noreply.github.com',
#       'name': 'aksu07'},
#      'message': 'Update FirsClassCodes.java\n\nfirst commit from remote repository',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aksu07/git_proje_turkce/commits/601d237744dd8f9a925c1093d77897a9e0cb0286'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197988',
#   'type': 'IssuesEvent',
#   'actor': {'id': 55872350,
#    'login': 'OPlobo',
#    'display_login': 'OPlobo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/OPlobo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55872350?'},
#   'repo': {'id': 273828795,
#    'name': 'OPlobo/OPlobo.github.io',
#    'url': 'https://api.github.com/repos/OPlobo/OPlobo.github.io'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/OPlobo/OPlobo.github.io/issues/2',
#     'repository_url': 'https://api.github.com/repos/OPlobo/OPlobo.github.io',
#     'labels_url': 'https://api.github.com/repos/OPlobo/OPlobo.github.io/issues/2/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/OPlobo/OPlobo.github.io/issues/2/comments',
#     'events_url': 'https://api.github.com/repos/OPlobo/OPlobo.github.io/issues/2/events',
#     'html_url': 'https://github.com/OPlobo/OPlobo.github.io/issues/2',
#     'id': 642491494,
#     'node_id': 'MDU6SXNzdWU2NDI0OTE0OTQ=',
#     'number': 2,
#     'title': 'Update API documentation',
#     'user': {'login': 'OPlobo',
#      'id': 55872350,
#      'node_id': 'MDQ6VXNlcjU1ODcyMzUw',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/55872350?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/OPlobo',
#      'html_url': 'https://github.com/OPlobo',
#      'followers_url': 'https://api.github.com/users/OPlobo/followers',
#      'following_url': 'https://api.github.com/users/OPlobo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/OPlobo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/OPlobo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/OPlobo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/OPlobo/orgs',
#      'repos_url': 'https://api.github.com/users/OPlobo/repos',
#      'events_url': 'https://api.github.com/users/OPlobo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/OPlobo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-06-21T04:16:55Z',
#     'updated_at': '2020-06-21T04:16:55Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': ''}},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197987',
#   'type': 'WatchEvent',
#   'actor': {'id': 1470061,
#    'login': 'patrickcurl',
#    'display_login': 'patrickcurl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/patrickcurl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1470061?'},
#   'repo': {'id': 249063259,
#    'name': 'ianramzy/decentralized-video-chat',
#    'url': 'https://api.github.com/repos/ianramzy/decentralized-video-chat'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197982',
#   'type': 'PushEvent',
#   'actor': {'id': 17193977,
#    'login': 'newstools',
#    'display_login': 'newstools',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/newstools',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17193977?'},
#   'repo': {'id': 231702948,
#    'name': 'newstools/2020-leadership-newspaper-nigeria',
#    'url': 'https://api.github.com/repos/newstools/2020-leadership-newspaper-nigeria'},
#   'payload': {'push_id': 5260359759,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6b8d60a7c46b2599a6e75136b6ea77b52e91b37d',
#    'before': '5bce8008fe8e61fa82f23890931760087281b624',
#    'commits': [{'sha': '6b8d60a7c46b2599a6e75136b6ea77b52e91b37d',
#      'author': {'email': 'github@newstools.co.za', 'name': 'NewsTools'},
#      'message': 'Created Text For URL [leadership.ng/2020/06/21/police-launches-manhunt-for-killers-of-abuja-business-man/]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/newstools/2020-leadership-newspaper-nigeria/commits/6b8d60a7c46b2599a6e75136b6ea77b52e91b37d'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197981',
#   'type': 'PushEvent',
#   'actor': {'id': 39196690,
#    'login': 'lokesh216',
#    'display_login': 'lokesh216',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lokesh216',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39196690?'},
#   'repo': {'id': 273172520,
#    'name': 'lokesh216/Playground',
#    'url': 'https://api.github.com/repos/lokesh216/Playground'},
#   'payload': {'push_id': 5260359756,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7d17557b52568de01426062e186315db0dae10bb',
#    'before': '02c5a574844fe4b27363c8c82b0779c246ebddca',
#    'commits': [{'sha': '7d17557b52568de01426062e186315db0dae10bb',
#      'author': {'email': '39196690+lokesh216@users.noreply.github.com',
#       'name': 'lokesh216'},
#      'message': 'Test code pushed to repository.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lokesh216/Playground/commits/7d17557b52568de01426062e186315db0dae10bb'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197980',
#   'type': 'WatchEvent',
#   'actor': {'id': 63765333,
#    'login': 'blaze1DoC',
#    'display_login': 'blaze1DoC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/blaze1DoC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63765333?'},
#   'repo': {'id': 31028375,
#    'name': 'DefectDojo/django-DefectDojo',
#    'url': 'https://api.github.com/repos/DefectDojo/django-DefectDojo'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z',
#   'org': {'id': 35606478,
#    'login': 'DefectDojo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DefectDojo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35606478?'}},
#  {'id': '12689197977',
#   'type': 'PushEvent',
#   'actor': {'id': 57664074,
#    'login': 'ArthurGodoy10',
#    'display_login': 'ArthurGodoy10',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ArthurGodoy10',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57664074?'},
#   'repo': {'id': 267045541,
#    'name': 'ArthurGodoy10/Projeto-de-Programacao-para-a-Web',
#    'url': 'https://api.github.com/repos/ArthurGodoy10/Projeto-de-Programacao-para-a-Web'},
#   'payload': {'push_id': 5260359752,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '02b423df068c28f03f2f7543e7d2c16e94b6b21c',
#    'before': 'c3e307e67aeb6d9d101a5694716545e6479ffb14',
#    'commits': [{'sha': '02b423df068c28f03f2f7543e7d2c16e94b6b21c',
#      'author': {'email': '2014arthur@gmail.com', 'name': 'Arthur Couto'},
#      'message': 'Update index.php\n\nAtualização feita no no index, onde foi modificado e melhorado.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ArthurGodoy10/Projeto-de-Programacao-para-a-Web/commits/02b423df068c28f03f2f7543e7d2c16e94b6b21c'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197971',
#   'type': 'PushEvent',
#   'actor': {'id': 25180681,
#    'login': 'renovate-bot',
#    'display_login': 'renovate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#   'repo': {'id': 238286105,
#    'name': 'renovate-bot/python-texttospeech',
#    'url': 'https://api.github.com/repos/renovate-bot/python-texttospeech'},
#   'payload': {'push_id': 5260359744,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '887d8d501ce9255fee44170b5fc40ebfb1ea953d',
#    'before': '887d8d501ce9255fee44170b5fc40ebfb1ea953d',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197968',
#   'type': 'PublicEvent',
#   'actor': {'id': 30179708,
#    'login': 'kaibaooo',
#    'display_login': 'kaibaooo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kaibaooo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30179708?'},
#   'repo': {'id': 273264541,
#    'name': 'kaibaooo/CUDA-Memory-Access-Pattern-Sample',
#    'url': 'https://api.github.com/repos/kaibaooo/CUDA-Memory-Access-Pattern-Sample'},
#   'payload': {},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197966',
#   'type': 'CreateEvent',
#   'actor': {'id': 67215205,
#    'login': 'terry2020-web',
#    'display_login': 'terry2020-web',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/terry2020-web',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67215205?'},
#   'repo': {'id': 273832552,
#    'name': 'terry2020-web/Coursera_Capstone',
#    'url': 'https://api.github.com/repos/terry2020-web/Coursera_Capstone'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Coursera_Capstone',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197963',
#   'type': 'PushEvent',
#   'actor': {'id': 43764425,
#    'login': 'QingliangZhao',
#    'display_login': 'QingliangZhao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/QingliangZhao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43764425?'},
#   'repo': {'id': 273832408,
#    'name': 'QingliangZhao/Mapping_Earthquakes',
#    'url': 'https://api.github.com/repos/QingliangZhao/Mapping_Earthquakes'},
#   'payload': {'push_id': 5260359743,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3c317a62f768201f0e7d98fb6c047eff3f22ddf7',
#    'before': '24650384dfa63b6a2f6a85b558467f2f896b1425',
#    'commits': [{'sha': '3c317a62f768201f0e7d98fb6c047eff3f22ddf7',
#      'author': {'email': '43764425+QingliangZhao@users.noreply.github.com',
#       'name': 'QingliangZhao'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/QingliangZhao/Mapping_Earthquakes/commits/3c317a62f768201f0e7d98fb6c047eff3f22ddf7'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197964',
#   'type': 'CreateEvent',
#   'actor': {'id': 21017157,
#    'login': 'gammaflauge',
#    'display_login': 'gammaflauge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gammaflauge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21017157?'},
#   'repo': {'id': 273832551,
#    'name': 'gammaflauge/ugh',
#    'url': 'https://api.github.com/repos/gammaflauge/ugh'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-21T04:16:55Z'},
#  {'id': '12689197958',
#   'type': 'PushEvent',
#   'actor': {'id': 42299295,
#    'login': 'nur-bot',
#    'display_login': 'nur-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nur-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42299295?'},
#   'repo': {'id': 123327588,
#    'name': 'nix-community/NUR',
#    'url': 'https://api.github.com/repos/nix-community/NUR'},
#   'payload': {'push_id': 5260359739,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6043706770fa56f27b094ee5e8174ca980412422',
#    'before': '6d67654916958c25d9d03acbe859390b34e86e1f',
#    'commits': [{'sha': '6043706770fa56f27b094ee5e8174ca980412422',
#      'author': {'email': 'joerg.nur-bot@thalheim.io', 'name': 'Nur a bot'},
#      'message': 'automatic update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nix-community/NUR/commits/6043706770fa56f27b094ee5e8174ca980412422'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z',
#   'org': {'id': 33221035,
#    'login': 'nix-community',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nix-community',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33221035?'}},
#  {'id': '12689197957',
#   'type': 'PushEvent',
#   'actor': {'id': 44589562,
#    'login': 'davisidarta',
#    'display_login': 'davisidarta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/davisidarta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44589562?'},
#   'repo': {'id': 227765123,
#    'name': 'davisidarta/dbMAP',
#    'url': 'https://api.github.com/repos/davisidarta/dbMAP'},
#   'payload': {'push_id': 5260359737,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '760e9f617c397cb2a82f147f3c69bddea417ca9a',
#    'before': 'ffbae08729896298e9168689845e79889189731a',
#    'commits': [{'sha': '760e9f617c397cb2a82f147f3c69bddea417ca9a',
#      'author': {'email': '44589562+davisidarta@users.noreply.github.com',
#       'name': 'davisidarta'},
#      'message': 'Create ann.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/davisidarta/dbMAP/commits/760e9f617c397cb2a82f147f3c69bddea417ca9a'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z'},
#  {'id': '12689197961',
#   'type': 'WatchEvent',
#   'actor': {'id': 994282,
#    'login': 'goldeneggg',
#    'display_login': 'goldeneggg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/goldeneggg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/994282?'},
#   'repo': {'id': 47648925,
#    'name': 'awslabs/aws-cloudformation-templates',
#    'url': 'https://api.github.com/repos/awslabs/aws-cloudformation-templates'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z',
#   'org': {'id': 3299148,
#    'login': 'awslabs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/awslabs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3299148?'}},
#  {'id': '12689197956',
#   'type': 'PushEvent',
#   'actor': {'id': 7856706,
#    'login': 'a19860101',
#    'display_login': 'a19860101',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/a19860101',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7856706?'},
#   'repo': {'id': 266466131,
#    'name': 'a19860101/PHP-0-20200524',
#    'url': 'https://api.github.com/repos/a19860101/PHP-0-20200524'},
#   'payload': {'push_id': 5260359738,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c8ae0aa0f6e58d6926d092794a8ec24eae26a8cf',
#    'before': '7035908534db442a59758c6994792c0122097742',
#    'commits': [{'sha': 'c8ae0aa0f6e58d6926d092794a8ec24eae26a8cf',
#      'author': {'email': 'a19860101@gmail.com', 'name': 'Zac'},
#      'message': '20200621',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/a19860101/PHP-0-20200524/commits/c8ae0aa0f6e58d6926d092794a8ec24eae26a8cf'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z'},
#  {'id': '12689197959',
#   'type': 'WatchEvent',
#   'actor': {'id': 45444088,
#    'login': 'GabrielVais',
#    'display_login': 'GabrielVais',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GabrielVais',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45444088?'},
#   'repo': {'id': 98883508,
#    'name': 'epicmaxco/vuestic-admin',
#    'url': 'https://api.github.com/repos/epicmaxco/vuestic-admin'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z',
#   'org': {'id': 30595047,
#    'login': 'epicmaxco',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/epicmaxco',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30595047?'}},
#  {'id': '12689197954',
#   'type': 'PushEvent',
#   'actor': {'id': 65295669,
#    'login': 'insane-monkey',
#    'display_login': 'insane-monkey',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/insane-monkey',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65295669?'},
#   'repo': {'id': 263672410,
#    'name': 'git-roll/expert-garbanzo',
#    'url': 'https://api.github.com/repos/git-roll/expert-garbanzo'},
#   'payload': {'push_id': 5260359735,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/fix-f-dMNp_hwE',
#    'head': 'f5fbf42b0b0706f1624acef0ce78094f373ca128',
#    'before': 'd443f66cc4b6fd46b2c6c86c42c35f8a5b5c82ce',
#    'commits': [{'sha': 'f5fbf42b0b0706f1624acef0ce78094f373ca128',
#      'author': {'email': 'insane.monkey@releases.fyi',
#       'name': 'insane-monkey'},
#      'message': '[TBS]Create f-ij7WG7rj\nReplace 1q/dzqbx]N!&.Af%4-%hdx+B&YW%diC}_Ln/vf^%uw?}:$3l6&.0hUG5*p;HHVN_nA"=:H%W#wbWDj w/1q/dzqbx]N!&.Af%4-%hdx+B&YkDLjk ";vaq8BBz1oMn\nDelete I__g-d5x',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/git-roll/expert-garbanzo/commits/f5fbf42b0b0706f1624acef0ce78094f373ca128'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z',
#   'org': {'id': 63239334,
#    'login': 'git-roll',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/git-roll',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63239334?'}},
#  {'id': '12689197952',
#   'type': 'PushEvent',
#   'actor': {'id': 28396602,
#    'login': 'fazlurnu',
#    'display_login': 'fazlurnu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fazlurnu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28396602?'},
#   'repo': {'id': 271033314,
#    'name': 'fazlurnu/SultengLawanCovid-Content',
#    'url': 'https://api.github.com/repos/fazlurnu/SultengLawanCovid-Content'},
#   'payload': {'push_id': 5260359734,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'edbe51b74acb5799026450d3a9a289743238a439',
#    'before': '8dd44cd751b8a9bf2665447237029f44a09f3176',
#    'commits': [{'sha': 'edbe51b74acb5799026450d3a9a289743238a439',
#      'author': {'email': 'fazlur.rahman.ae@gmail.com',
#       'name': 'Fazlur Rahman'},
#      'message': 'define get_ROI',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fazlurnu/SultengLawanCovid-Content/commits/edbe51b74acb5799026450d3a9a289743238a439'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z'},
#  {'id': '12689197953',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 49757946,
#    'login': 'LegendWasTaken',
#    'display_login': 'LegendWasTaken',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LegendWasTaken',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49757946?'},
#   'repo': {'id': 258025388,
#    'name': 'GraphicsProgramming/RVPT',
#    'url': 'https://api.github.com/repos/GraphicsProgramming/RVPT'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/GraphicsProgramming/RVPT/pulls/comments/443179944',
#     'pull_request_review_id': 434468381,
#     'id': 443179944,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDQ0MzE3OTk0NA==',
# ...
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/p1ass/midare',
#       'description': '🕒  ツイートを使って生活習慣の乱れを可視化するWebアプリ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/p1ass/midare',
#       'forks_url': 'https://api.github.com/repos/p1ass/midare/forks',
#       'keys_url': 'https://api.github.com/repos/p1ass/midare/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/p1ass/midare/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/p1ass/midare/teams',
#       'hooks_url': 'https://api.github.com/repos/p1ass/midare/hooks',
#       'issue_events_url': 'https://api.github.com/repos/p1ass/midare/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/p1ass/midare/events',
#       'assignees_url': 'https://api.github.com/repos/p1ass/midare/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/p1ass/midare/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/p1ass/midare/tags',
#       'blobs_url': 'https://api.github.com/repos/p1ass/midare/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/p1ass/midare/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/p1ass/midare/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/p1ass/midare/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/p1ass/midare/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/p1ass/midare/languages',
#       'stargazers_url': 'https://api.github.com/repos/p1ass/midare/stargazers',
#       'contributors_url': 'https://api.github.com/repos/p1ass/midare/contributors',
#       'subscribers_url': 'https://api.github.com/repos/p1ass/midare/subscribers',
#       'subscription_url': 'https://api.github.com/repos/p1ass/midare/subscription',
#       'commits_url': 'https://api.github.com/repos/p1ass/midare/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/p1ass/midare/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/p1ass/midare/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/p1ass/midare/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/p1ass/midare/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/p1ass/midare/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/p1ass/midare/merges',
#       'archive_url': 'https://api.github.com/repos/p1ass/midare/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/p1ass/midare/downloads',
#       'issues_url': 'https://api.github.com/repos/p1ass/midare/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/p1ass/midare/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/p1ass/midare/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/p1ass/midare/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/p1ass/midare/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/p1ass/midare/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/p1ass/midare/deployments',
#       'created_at': '2020-05-23T10:28:45Z',
#       'updated_at': '2020-06-21T03:53:48Z',
#       'pushed_at': '2020-06-21T04:16:53Z',
#       'git_url': 'git://github.com/p1ass/midare.git',
#       'ssh_url': 'git@github.com:p1ass/midare.git',
#       'clone_url': 'https://github.com/p1ass/midare.git',
#       'svn_url': 'https://github.com/p1ass/midare',
#       'homepage': 'https://midare.p1ass.com',
#       'size': 1855,
#       'stargazers_count': 111,
#       'watchers_count': 111,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 111,
#       'default_branch': 'master'}},
#     'base': {'label': 'p1ass:master',
#      'ref': 'master',
#      'sha': '0846e5c391b125a905c489414bcd918ec56f71e7',
#      'user': {'login': 'p1ass',
#       'id': 30015728,
#       'node_id': 'MDQ6VXNlcjMwMDE1NzI4',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/30015728?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/p1ass',
#       'html_url': 'https://github.com/p1ass',
#       'followers_url': 'https://api.github.com/users/p1ass/followers',
#       'following_url': 'https://api.github.com/users/p1ass/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/p1ass/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/p1ass/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/p1ass/subscriptions',
#       'organizations_url': 'https://api.github.com/users/p1ass/orgs',
#       'repos_url': 'https://api.github.com/users/p1ass/repos',
#       'events_url': 'https://api.github.com/users/p1ass/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/p1ass/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 266313259,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjYzMTMyNTk=',
#       'name': 'midare',
#       'full_name': 'p1ass/midare',
#       'private': False,
#       'owner': {'login': 'p1ass',
#        'id': 30015728,
#        'node_id': 'MDQ6VXNlcjMwMDE1NzI4',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/30015728?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/p1ass',
#        'html_url': 'https://github.com/p1ass',
#        'followers_url': 'https://api.github.com/users/p1ass/followers',
#        'following_url': 'https://api.github.com/users/p1ass/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/p1ass/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/p1ass/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/p1ass/subscriptions',
#        'organizations_url': 'https://api.github.com/users/p1ass/orgs',
#        'repos_url': 'https://api.github.com/users/p1ass/repos',
#        'events_url': 'https://api.github.com/users/p1ass/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/p1ass/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/p1ass/midare',
#       'description': '🕒  ツイートを使って生活習慣の乱れを可視化するWebアプリ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/p1ass/midare',
#       'forks_url': 'https://api.github.com/repos/p1ass/midare/forks',
#       'keys_url': 'https://api.github.com/repos/p1ass/midare/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/p1ass/midare/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/p1ass/midare/teams',
#       'hooks_url': 'https://api.github.com/repos/p1ass/midare/hooks',
#       'issue_events_url': 'https://api.github.com/repos/p1ass/midare/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/p1ass/midare/events',
#       'assignees_url': 'https://api.github.com/repos/p1ass/midare/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/p1ass/midare/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/p1ass/midare/tags',
#       'blobs_url': 'https://api.github.com/repos/p1ass/midare/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/p1ass/midare/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/p1ass/midare/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/p1ass/midare/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/p1ass/midare/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/p1ass/midare/languages',
#       'stargazers_url': 'https://api.github.com/repos/p1ass/midare/stargazers',
#       'contributors_url': 'https://api.github.com/repos/p1ass/midare/contributors',
#       'subscribers_url': 'https://api.github.com/repos/p1ass/midare/subscribers',
#       'subscription_url': 'https://api.github.com/repos/p1ass/midare/subscription',
#       'commits_url': 'https://api.github.com/repos/p1ass/midare/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/p1ass/midare/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/p1ass/midare/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/p1ass/midare/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/p1ass/midare/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/p1ass/midare/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/p1ass/midare/merges',
#       'archive_url': 'https://api.github.com/repos/p1ass/midare/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/p1ass/midare/downloads',
#       'issues_url': 'https://api.github.com/repos/p1ass/midare/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/p1ass/midare/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/p1ass/midare/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/p1ass/midare/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/p1ass/midare/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/p1ass/midare/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/p1ass/midare/deployments',
#       'created_at': '2020-05-23T10:28:45Z',
#       'updated_at': '2020-06-21T03:53:48Z',
#       'pushed_at': '2020-06-21T04:16:53Z',
#       'git_url': 'git://github.com/p1ass/midare.git',
#       'ssh_url': 'git@github.com:p1ass/midare.git',
#       'clone_url': 'https://github.com/p1ass/midare.git',
#       'svn_url': 'https://github.com/p1ass/midare',
#       'homepage': 'https://midare.p1ass.com',
#       'size': 1855,
#       'stargazers_count': 111,
#       'watchers_count': 111,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 111,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/p1ass/midare/pulls/75'},
#      'html': {'href': 'https://github.com/p1ass/midare/pull/75'},
#      'issue': {'href': 'https://api.github.com/repos/p1ass/midare/issues/75'},
#      'comments': {'href': 'https://api.github.com/repos/p1ass/midare/issues/75/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/p1ass/midare/pulls/75/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/p1ass/midare/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/p1ass/midare/pulls/75/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/p1ass/midare/statuses/7d7d3b131fe06d3c5bdfe7c848c66a5b14a934ae'}},
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'p1ass',
#      'id': 30015728,
#      'node_id': 'MDQ6VXNlcjMwMDE1NzI4',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/30015728?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/p1ass',
#      'html_url': 'https://github.com/p1ass',
#      'followers_url': 'https://api.github.com/users/p1ass/followers',
#      'following_url': 'https://api.github.com/users/p1ass/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/p1ass/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/p1ass/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/p1ass/subscriptions',
#      'organizations_url': 'https://api.github.com/users/p1ass/orgs',
#      'repos_url': 'https://api.github.com/users/p1ass/repos',
#      'events_url': 'https://api.github.com/users/p1ass/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/p1ass/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 5,
#     'deletions': 5,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z'},
#  {'id': '12689197946',
#   'type': 'PushEvent',
#   'actor': {'id': 6383265,
#    'login': 'terminal98',
#    'display_login': 'terminal98',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/terminal98',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6383265?'},
#   'repo': {'id': 273831474,
#    'name': 'terminal98/doc.t98.info',
#    'url': 'https://api.github.com/repos/terminal98/doc.t98.info'},
#   'payload': {'push_id': 5260359731,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '724a0e402ec1af9a9a8c3ccbefe2ffb51b142e30',
#    'before': '866fb9b4004febcc70e4ab8d69eea0e0563f560d',
#    'commits': [{'sha': '724a0e402ec1af9a9a8c3ccbefe2ffb51b142e30',
#      'author': {'email': 'git@t98.info', 'name': 'git@t98.info'},
#      'message': 'add index md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/terminal98/doc.t98.info/commits/724a0e402ec1af9a9a8c3ccbefe2ffb51b142e30'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z'},
#  {'id': '12689197943',
#   'type': 'WatchEvent',
#   'actor': {'id': 63765333,
#    'login': 'blaze1DoC',
#    'display_login': 'blaze1DoC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/blaze1DoC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63765333?'},
#   'repo': {'id': 197275130,
#    'name': 'microsoft/winget-cli',
#    'url': 'https://api.github.com/repos/microsoft/winget-cli'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z',
#   'org': {'id': 6154722,
#    'login': 'microsoft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/microsoft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?'}},
#  {'id': '12689197944',
#   'type': 'CreateEvent',
#   'actor': {'id': 55770430,
#    'login': 'noreederek',
#    'display_login': 'noreederek',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/noreederek',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55770430?'},
#   'repo': {'id': 273575713,
#    'name': 'ergottli/tel_med',
#    'url': 'https://api.github.com/repos/ergottli/tel_med'},
#   'payload': {'ref': 'develop_nderek',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z'},
#  {'id': '12689197939',
#   'type': 'PushEvent',
#   'actor': {'id': 67203623,
#    'login': 'codershut',
#    'display_login': 'codershut',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codershut',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67203623?'},
#   'repo': {'id': 273827326,
#    'name': 'codershut/course1',
#    'url': 'https://api.github.com/repos/codershut/course1'},
#   'payload': {'push_id': 5260359725,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3b4b880ed7f8c341ae987c8b0d50cd8264e35e15',
#    'before': '5ad46ef182d0c4db1711d8bfd66edf33de8528f1',
#    'commits': [{'sha': '3b4b880ed7f8c341ae987c8b0d50cd8264e35e15',
#      'author': {'email': '67203623+codershut@users.noreply.github.com',
#       'name': 'codershut'},
#      'message': 'Delete djd',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/codershut/course1/commits/3b4b880ed7f8c341ae987c8b0d50cd8264e35e15'}]},
#   'public': True,
#   'created_at': '2020-06-21T04:16:54Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
 payload={'key1':'value1','key2':'value2'}
r=requests.get("https://cat-fact.herokuapp.com/facts/get",params=payload)
json.loads(r.text)

#params是固定參數
# Out:
# {'stringValue': '"get"',
#  'kind': 'ObjectId',
#  'value': 'get',
#  'path': '_id',
#  'reason': {},
#  'message': 'Cast to ObjectId failed for value "get" at path "_id" for model "Fact"',
#  'name': 'CastError'}

# %%
r=requests.post('https://cat-fact.herokuapp.com/facts/post',data={'key':'value'})
json.loads(r.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-1de19302c6db> in <module>
#       1 r=requests.post('https://cat-fact.herokuapp.com/facts/post',data={'key':'value'})
# ----> 2 json.loads(r.text)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
